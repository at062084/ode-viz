# %% [markdown]
# # EDA Tools Comparison Notebook
#
# This notebook provides a comprehensive comparison of Python EDA (Exploratory Data Analysis) tools available in the OpenDataExplorer project.
#
# ## Purpose
# Evaluate and demonstrate various Python EDA libraries to help users understand which tool best fits their analysis needs.
#
# ## Reference
# Based on: [10 Best Python EDA Tools](https://medium.com/top-python-libraries/10-best-python-eda-tools-transform-data-analysis-fast-aa4563174f4e)
#
# ---
#
# ## Python 3.10 Compatibility Results
# Results with Python 3.10 are generally better than with Python 3.13
#
# ### ✅ Working Tools
# - **SummaryTools**: OK - Fast statistical summaries
# - **D-Tale**: OK - Interactive Flask/React interface
# - **Sweetviz**: OK - Beautiful HTML visualizations
# - **Dataprep**: OK - Fastest report generation
# - **Dabl**: OK (After downgrading scikit-learn from 1.6.1 to 1.2)
# - **Klib**: OK - Convenient for custom analyses
# - **DataTile**: OK - Extended DataFrame describe()
#
# ### ❌ Not Working
# - **AutoViz**: KO - Errors reading CSV files
# - **ydata-profiling**: KO - Requirements.txt errors
# - **edaviz**: KO - No longer open source (acquired by Databricks)
#
# ## Python 3.13 Compatibility Results
#
# ### ✅ Working
# - SummaryTools: OK
# - D-Tale: OK
# - Sweetviz: OK
# - Klib: OK (weird output)
# - Dabl: OK (weird output)
# - DataTile: OK (Application Error on some data: could not convert string to float)
# - AutoViz: OK (Output formatting issues)
#
# ### ❌ Not Working
# - ydata-profiling: KO - No version available for Python 3.13
# - Dataprep: KO - Failed to build levenshtein pandas
# - edaviz: KO - No longer open source
#
# ---

# %% [markdown]
# # summarytools

# %%
import pandas as pd
from summarytools import dfSummary

# %%
import os

# Use DATA_ROOT_DIR from environment
csv_path = os.path.join(os.environ['DATA_ROOT_DIR'], 'download', 'OGD', 'AMS', 'AL_SC_Geschlecht_Bdl_ZR.csv')

print(f"Loading data from: {csv_path}")

df = pd.read_csv(csv_path, sep=';', encoding='ISO-8859-1')
df['Datum'] = pd.to_datetime(df['Datum'], format='%Y-%m-%d')
df.info()

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_9bd41 thead>tr>th {
#   text-align: left;
# }
# #T_9bd41_row0_col0, #T_9bd41_row1_col0, #T_9bd41_row2_col0, #T_9bd41_row3_col0, #T_9bd41_row4_col0, #T_9bd41_row5_col0, #T_9bd41_row6_col0, #T_9bd41_row7_col0, #T_9bd41_row8_col0, #T_9bd41_row9_col0, #T_9bd41_row10_col0, #T_9bd41_row11_col0, #T_9bd41_row12_col0, #T_9bd41_row13_col0, #T_9bd41_row14_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_9bd41_row0_col1, #T_9bd41_row1_col1, #T_9bd41_row2_col1, #T_9bd41_row3_col1, #T_9bd41_row4_col1, #T_9bd41_row5_col1, #T_9bd41_row6_col1, #T_9bd41_row7_col1, #T_9bd41_row8_col1, #T_9bd41_row9_col1, #T_9bd41_row10_col1, #T_9bd41_row11_col1, #T_9bd41_row12_col1, #T_9bd41_row13_col1, #T_9bd41_row14_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %% [markdown]
# # D-Tale
#
# D-Tale uses Flask for the backend, React for the frontend, and integrates seamlessly with IPython notebooks and terminals.
#
# D-Tale supports Pandas DataFrame, Series, MultiIndex, DatetimeIndex, and RangeIndex.

# %%
import dtale
dtale.show(df, eager_loading=True)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://li-96f0d1cc-245c-11b2-a85c-ca3e434889f3.ibm.com:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2025-03-19 11:39:50,512 - INFO     - Executing shutdown due to inactivity...
# 2025-03-19 11:39:50,522 - INFO     - Executing shutdown...
# 2025-03-19 11:39:50,523 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %% [markdown]
# # Sweetviz
#
# Sweetviz is an open-source Python library that generates beautiful visualizations with just two lines of code, launching EDA as an HTML application.
#
# It is built for quick visualization of target values and comparing datasets.

# %%
# Run into error: No module named 'distutils'. depricated in 3.12
import sweetviz as sv

#EDA using Autoviz
sweet_report = sv.analyze(df)

#Saving results to HTML file
# sweet_report.show_html('sweetviz.html')
sweet_report.show_notebook(layout='widescreen')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# /home/aty9h2px/bin/venvs/python-3.10/lib64/python3.10/site-packages/sweetviz/series_analyzer.py:17: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# # Dataprep
#
# Dataprep is an open-source Python package for analyzing, preparing, and processing data.
#
# Built on Pandas and Dask DataFrame, Dataprep integrates easily with other Python libraries.
#
# Dataprep is the fastest among these packages, generating reports for Pandas/Dask DataFrame in seconds.
#
# pip install dataprep
#
# after download of many different versions of several packages:
#
# Successfully built metaphone numpy regex
# Failed to build levenshtein pandas
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (levenshtein, pandas)

# %%
from dataprep.datasets import load_dataset
from dataprep.eda import create_report

# Opens new page in standard browser
create_report(df).show_browser()
# Out:
#   0%|          | 0/2406 [00:00<?, ?it/s]

# %% [markdown]
# # klib
#
# Klib is a Python library for importing, cleaning, analyzing, and preprocessing data.
#
# While Klib offers many analysis functions, each requires manual coding, making it semi-automated. However, it is very convenient for custom analyses.

# %%
import klib
import klib.describe

# klib.missingval_plot(df)
# klib.corr_plot(df, split='pos')
klib.convert_datatypes(df)
# Out:
#           Datum Status        StatusBez Geschlecht   Bgld    Ktn    NOe  \
# 0    1987-01-27     AL  AL - arbeitslos     Frauen   3131   7636  13742
# 1    1987-01-27     AL  AL - arbeitslos     Männer  10483  18503  28746
# 2    1987-01-27     SC    SC - Schulung     Frauen    368    768    701
# 3    1987-01-27     SC    SC - Schulung     Männer    279    680    876
# 4    1987-02-27     AL  AL - arbeitslos     Frauen   3024   7210  13494
# ...         ...    ...              ...        ...    ...    ...    ...
# 1819 2024-11-30     SC    SC - Schulung     Männer    824   1177   4255
# 1820 2024-12-31     AL  AL - arbeitslos     Frauen   4046   8047  21433
# 1821 2024-12-31     AL  AL - arbeitslos     Männer   6075  14300  31542
# 1822 2024-12-31     SC    SC - Schulung     Frauen    943   1816   5065
# 1823 2024-12-31     SC    SC - Schulung     Männer    711   1058   3868
#
#         OOe   Sbg   Stmk  Tirol   Vbg   Wien      AT  Unnamed: 14
# ...

# %% [markdown]
# # dabl
#
# Dabl focuses on providing quick overviews through visualization and convenient machine learning preprocessing and model search rather than individual column statistics.
#
# The `plot()` function in Dabl visualizes various plots, including:
#
#     Target distribution plots
#     Scatter plots
#     Linear discriminant analysis

# %%
import dabl

dabl.detect_types(df)

# not applicable to non-ML dataset
# dabl.plot(df, 'Status')
# Out:
#              continuous  dirty_float  low_card_int_ordinal  \
# Datum           False       False             False
# Status          False       False             False
# StatusBez       False       False             False
# Geschlecht      False       False             False
# Bgld             True       False             False
# Ktn              True       False             False
# NOe              True       False             False
# OOe              True       False             False
# Sbg              True       False             False
# Stmk             True       False             False
# Tirol            True       False             False
# Vbg              True       False             False
# Wien             True       False             False
# AT               True       False             False
# Unnamed: 14     False       False             False
#
#              low_card_int_categorical  categorical  date   free_string  \
# ...

# %% [markdown]
# # DataTile
#
# DataTile (formerly Pandas-Summary) is an open-source Python package for managing, summarizing, and visualizing data.
#
# It extends the Pandas DataFrame `describe()` function.

# %%
from datatile.summary.df import DataFrameSummary

dg = df
# dg = df.drop(df.columns[['Datum']])
dgs = DataFrameSummary(dg)
dgs.summary()
# Out:
# /home/aty9h2px/bin/venvs/python-3.10/lib64/python3.10/site-packages/datatile/summary/df.py:39: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#              Datum Status StatusBez Geschlecht         Bgld          Ktn  \
# count          NaN    NaN       NaN        NaN       1824.0       1824.0
# mean           NaN    NaN       NaN        NaN  2249.747259   5204.49068
# std            NaN    NaN       NaN        NaN    2031.1387  4933.912721
# min            NaN    NaN       NaN        NaN         41.0        111.0
# 25%            NaN    NaN       NaN        NaN       702.75       1024.0
# 50%            NaN    NaN       NaN        NaN       1304.0       2502.0
# 75%            NaN    NaN       NaN        NaN       3481.0       8533.5
# max            NaN    NaN       NaN        NaN      10483.0      21255.0
# ...

# %% [markdown]
# # Conclusion
#
# Dataprep is my most-used EDA package, with AutoViz and D-Tale being other excellent choices. Klib is convenient for custom analysis, while SpeedML’s comprehensive integration is less suited for EDA alone. Other packages can be chosen based on personal preference, though edaviz is no longer open-source.

# %% [markdown]
# # EDA packages not working in this setup

# %% [markdown]
# ## ydata-profiling
#
# ydata-profiling generates summary reports for Pandas DataFrame.
#
# It extends Pandas DataFrame with `df.profile_report()`, working efficiently on large datasets to create reports in seconds.

# %%
# no version for python 3.13

# %% [markdown]
# ## autoviz
#
# AutoViz automatically visualizes any size dataset with one line of code, generating reports in HTML, Bokeh, etc.
#
# Users can interact with HTML reports generated by AutoViz.

# %%
from autoviz.AutoViz_Class import AutoViz_Class
import os

# Use DATA_ROOT_DIR from environment
covid_file = os.path.join(os.environ['DATA_ROOT_DIR'], 'download', 'OGD', 'AMS', 'CovidFaelle_Timeline.csv')

print(f"Loading data from: {covid_file}")

# EDA using Autoviz
autoviz = AutoViz_Class().AutoViz(covid_file)

# %% [markdown]
# ## edaviz
#
# Edaviz is a Python library for data exploration and visualization in Jupyter Notebook and Jupyter Lab. It was highly useful but has since been integrated into Bamboolib after being acquired by Databricks. No longer open source
